# %% [markdown]
# # Análise de Dados Financeiros com Python

# %%
#Primeiro, vamos importar as bibliotecas.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# %%
#Aqui peguei os dados do ibovespa direito do yahoo finance passando o ticker, data source, data de inicio e fim.

cotacao_ibov = web.DataReader('^BVSP', data_source = 'yahoo', start ='2020-10-10', end ='2021-10-10')
display(cotacao_ibov)
# Out:
#                 High       Low      Open     Close      Volume  Adj Close
# Date
# 2020-10-13   98998.0   97336.0   97483.0   98503.0   7867500.0    98503.0
# 2020-10-14   99571.0   98501.0   98502.0   99334.0   8891000.0    99334.0
# 2020-10-15   99486.0   97778.0   99328.0   99054.0   8335200.0    99054.0
# 2020-10-16   99172.0   98309.0   99054.0   98309.0   7840200.0    98309.0
# 2020-10-19   99917.0   98310.0   98310.0   98658.0   9929400.0    98658.0
# ...              ...       ...       ...       ...         ...        ...
# 2021-10-04  112900.0  109979.0  112900.0  110393.0  11814200.0   110393.0
# 2021-10-05  111691.0  110087.0  110397.0  110458.0  10379000.0   110458.0
# 2021-10-06  110614.0  108180.0  110454.0  110560.0  13279200.0   110560.0
# 2021-10-07  111522.0  110563.0  110563.0  110585.0  10646000.0   110585.0
# 2021-10-08  114172.0  110586.0  110586.0  112833.0  12871400.0   112833.0
#
# [244 rows x 6 columns]

# %%
#Plotando um gráfico dos valores de fechamento do ibovespa.

cotacao_ibov['Adj Close'].plot(figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Calculando o retorno do ibovespa no período analisado.

retorno_ibov = cotacao_ibov['Adj Close'][-1] / cotacao_ibov['Adj Close'][0] -1
print ('O retorno do período analisado foi de: {:.2%}'.format(retorno_ibov))
# Out:
# O retorno do período analisado foi de: 14.55%

# %%
#Plot do gráfico do ibovespa com sua média móvel de 21 dias.

cotacao_ibov['Adj Close'].plot(figsize=(15, 5), label='IBOV')
cotacao_ibov['Adj Close'].rolling(21).mean().plot(label='MM21')

plt.legend()
plt.show()
